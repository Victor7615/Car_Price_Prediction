# %% [markdown]
# ## Installing Pyodbc Library

# %%
#!pip install pyodbc
# !pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in c:\users\user\anaconda3\newfolder\lib\site-packages (4.0.34)

# %%
# Importing Libraries

import pandas as pd
import pyodbc

# %% [markdown]
# ## Creating Connection to Database

# %%
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=DESKTOP-JQ0K1JM\SQLEXPRESS;DATABASE=Practice;Trusted_Connection=yes')
cursor=conn.cursor()#opening connection to the database

# %% [markdown]
# ## Read Data from Database

# %%
data=pd.read_sql_query(''' Select  * from dbo.car_price''',conn)

df_data=pd.DataFrame(data)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9584\4241679951.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data=pd.read_sql_query(''' Select  * from dbo.car_price''',conn)

# %%
df_data.head()
# Out:
#              Car_Name    Year  Present_Price  Kms_Driven Fuel_Type  \
# 0  Hero Passion X pro  2016.0       12417.55     33217.0    Petrol
# 1               xcent  2017.0       10633.13     12905.0    Petrol
# 2               verna  2015.0       10881.40     62053.0    Diesel
# 3              ertiga  2016.0       11107.79     43897.0    Diesel
# 4                jazz  2016.0       10316.40      4108.0    Petrol
#
#   Seller_Type Transmission  Owner  Selling_Price
# 0  Individual       Manual    0.0       11717.50
# 1      Dealer       Manual    0.0        9931.75
# 2      Dealer       Manual    0.0       10180.25
# 3      Dealer       Manual    0.0       10404.75
# 4      Dealer       Manual    0.0        9614.00

# %% [markdown]
# ## Exploratory Data Analysis Using Datasist Library
# ### Datasist Library
#
# datasist is a python package providing fast, quick, and an abstracted interface to popular and frequently used functions or techniques relating to data analysis, visualization, data exploration, feature engineering, Computer, NLP, Deep Learning, modeling, model deployment etc.

# %%
# installing datasist
# !pip install datasist
# Out:
# Requirement already satisfied: datasist in c:\users\user\anaconda3\newfolder\lib\site-packages (1.5.3)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (3.7.2)
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (0.12.2)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (1.23.4)
# Requirement already satisfied: jupyter in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (1.0.0)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (1.3.0)
# Requirement already satisfied: nltk in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (3.8.1)
# Requirement already satisfied: Joblib in c:\users\user\anaconda3\newfolder\lib\site-packages (from datasist) (1.2.0)
# Requirement already satisfied: notebook in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter->datasist) (6.5.4)
# Requirement already satisfied: qtconsole in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter->datasist) (5.4.2)
# Requirement already satisfied: jupyter-console in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter->datasist) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter->datasist) (6.5.4)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter->datasist) (6.25.0)
# Requirement already satisfied: ipywidgets in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter->datasist) (8.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\newfolder\lib\site-packages (from matplotlib->datasist) (2.8.2)
# Requirement already satisfied: click in c:\users\user\anaconda3\newfolder\lib\site-packages (from nltk->datasist) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nltk->datasist) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\newfolder\lib\site-packages (from nltk->datasist) (4.65.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from pandas->datasist) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from pandas->datasist) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from scikit-learn->datasist) (1.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from scikit-learn->datasist) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\newfolder\lib\site-packages (from python-dateutil>=2.7->matplotlib->datasist) (1.16.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\newfolder\lib\site-packages (from click->nltk->datasist) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (1.5.6)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipykernel->jupyter->datasist) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipywidgets->jupyter->datasist) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipywidgets->jupyter->datasist) (3.0.5)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter-console->jupyter->datasist) (3.0.36)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter-console->jupyter->datasist) (2.15.1)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (4.12.2)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbconvert->jupyter->datasist) (1.2.1)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\newfolder\lib\site-packages (from notebook->jupyter->datasist) (21.3.0)
# Requirement already satisfied: ipython-genutils in c:\users\user\anaconda3\newfolder\lib\site-packages (from notebook->jupyter->datasist) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from notebook->jupyter->datasist) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\newfolder\lib\site-packages (from notebook->jupyter->datasist) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\newfolder\lib\site-packages (from notebook->jupyter->datasist) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\user\anaconda3\newfolder\lib\site-packages (from notebook->jupyter->datasist) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from qtconsole->jupyter->datasist) (2.2.0)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\newfolder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->datasist) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->datasist) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->datasist) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter->datasist) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter->datasist) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\newfolder\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter->datasist) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\newfolder\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->datasist) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->datasist) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\newfolder\lib\site-packages (from argon2-cffi->notebook->jupyter->datasist) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\newfolder\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->datasist) (2.4)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\newfolder\lib\site-packages (from bleach->nbconvert->jupyter->datasist) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->datasist) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->datasist) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->datasist) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\user\anaconda3\newfolder\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->datasist) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->datasist) (1.15.1)
# Requirement already satisfied: executing in c:\users\user\anaconda3\newfolder\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\newfolder\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->datasist) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\newfolder\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\newfolder\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->datasist) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\newfolder\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->datasist) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\newfolder\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->datasist) (2.21)

# %%
import datasist as ds
import numpy as np

# %%
ds.structdata.describe(df_data)
# Out:
# First five data points
#              Car_Name    Year  Present_Price  Kms_Driven Fuel_Type  \
# 0  Hero Passion X pro  2016.0       12417.55     33217.0    Petrol
# 1               xcent  2017.0       10633.13     12905.0    Petrol
# 2               verna  2015.0       10881.40     62053.0    Diesel
# 3              ertiga  2016.0       11107.79     43897.0    Diesel
# 4                jazz  2016.0       10316.40      4108.0    Petrol
#
#   Seller_Type Transmission  Owner  Selling_Price
# 0  Individual       Manual    0.0       11717.50
# 1      Dealer       Manual    0.0        9931.75
# 2      Dealer       Manual    0.0       10180.25
# 3      Dealer       Manual    0.0       10404.75
# 4      Dealer       Manual    0.0        9614.00
# Random five data points
#                Car_Name    Year  Present_Price  Kms_Driven Fuel_Type  \
# 92037              jazz  2016.0       11306.50     16157.0    Petrol
# 49248              city  2016.0       12213.60     51562.0    Petrol
# 65479              city  2013.0        9151.90     55184.0    Petrol
# 54373         grand i10  2015.0       11810.70     22730.0    Diesel
# 9579   Yamaha FZ  v 2.0  2015.0       12298.84     31098.0    Petrol
#
#       Seller_Type Transmission  Owner  Selling_Price
# 92037      Dealer    Automatic    0.0       10605.40
# 49248      Dealer       Manual    0.0       11510.25
# 65479      Dealer       Manual    0.0        8447.25
# 54373      Dealer       Manual    0.0       11109.85
# 9579   Individual       Manual    0.0       11598.60
# Last five data points
#         Car_Name    Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 99995   alto 800  2017.0       10968.60      2900.0    Petrol      Dealer
# 99996  grand i10  2015.0       12575.70      6862.0    Petrol      Dealer
# 99997      dzire  2014.0        9229.06     46801.0    Diesel      Dealer
# 99998     ertiga  2015.0       10702.71     26365.0    Petrol      Dealer
# 99999       city  2015.0       11649.00     20267.0    Petrol      Dealer
#
#       Transmission  Owner  Selling_Price
# 99995       Manual    0.0       10267.85
# 99996       Manual    0.0       11875.50
# 99997       Manual    0.0        8526.50
# 99998       Manual    0.0       10000.80
# 99999       Manual    0.0       10945.70
# Shape of  data set: (100000, 9)
#
#
# Size of  data set: 900000
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#               Data Type
# Car_Name         object
# Year            float64
# Present_Price   float64
# Kms_Driven      float64
# Fuel_Type        object
# Seller_Type      object
# Transmission     object
# Owner           float64
# Selling_Price   float64
# Numerical Features in Data set
# ['Year', 'Present_Price', 'Kms_Driven', 'Owner', 'Selling_Price']
#
#
# Categorical Features in Data set
# ['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission']
# Statistical Description of Columns
#                 Year  Present_Price     Kms_Driven          Owner  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean     2014.059300   10454.815579   35544.731010       0.036080
# std         2.592811    1497.176036   35908.164469       0.213913
# min      2003.000000    3405.280000     606.000000       0.000000
# 25%      2013.000000    9406.007500   15760.000000       0.000000
# 50%      2015.000000   10628.705000   30595.500000       0.000000
# 75%      2016.000000   11639.782500   46476.000000       0.000000
# max      2018.000000   12731.230000  502479.000000       3.000000
#
#        Selling_Price
# count  100000.000000
# mean     9752.087633
# std      1498.468367
# min      2703.350000
# 25%      8703.250000
# 50%      9926.700000
# 75%     10938.120000
# max     12028.000000
# Description of Categorical Features
#                count unique     top   freq
# Car_Name      100000     98    city   8919
# Fuel_Type     100000      3  Petrol  78995
# Seller_Type   100000      2  Dealer  65615
# Transmission  100000      2  Manual  86541
# Unique class Count of Categorical features
# <style type="text/css">
# #T_12ea5_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_12ea5_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.1%, transparent 3.1%);
# }
# #T_12ea5_row2_col1, #T_12ea5_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.0%, transparent 2.0%);
# }
# </style>
# <table id="T_12ea5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12ea5_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_12ea5_level0_col1" class="col_heading level0 col1" >Unique Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12ea5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12ea5_row0_col0" class="data row0 col0" >Car_Name</td>
#       <td id="T_12ea5_row0_col1" class="data row0 col1" >98</td>
#     </tr>
#     <tr>
#       <th id="T_12ea5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12ea5_row1_col0" class="data row1 col0" >Fuel_Type</td>
#       <td id="T_12ea5_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_12ea5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12ea5_row2_col0" class="data row2 col0" >Seller_Type</td>
#       <td id="T_12ea5_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_12ea5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12ea5_row3_col0" class="data row3 col0" >Transmission</td>
#       <td id="T_12ea5_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# Missing Values in Data
#         features  missing_counts  missing_percent
# 0       Car_Name               0              0.0
# 1           Year               0              0.0
# 2  Present_Price               0              0.0
# 3     Kms_Driven               0              0.0
# 4      Fuel_Type               0              0.0
# 5    Seller_Type               0              0.0
# 6   Transmission               0              0.0
# 7          Owner               0              0.0
# 8  Selling_Price               0              0.0

# %%
# !pip install numpy==1.23.4
import warnings
import numpy as np
warnings.filterwarnings("ignore")
print("Version: ",np.__version__)
print("np.object: ",np.object)
# Out:
# Requirement already satisfied: numpy==1.23.4 in c:\users\user\anaconda3\newfolder\lib\site-packages (1.23.4)
# Version:  1.23.4
# np.object:  <class 'object'>

# %%
ds.visualizations.countplot(df_data)
# Out:
# Unique Values in Car_Name is too large to plot

# %%
ds.visualizations.countplot(df_data,separate_by="Seller_Type")
# Out:
# Unique Values in Car_Name is too large to plot

# %% [markdown]
# ## Feature Engineering
#
# Feature Engineering is the process of using domain knowledge to select and transform features from raw data before building a predictive model using Machine learning.
#
#
# Actions
#
#
# 1.Handling missing values
#
# 2.Creating new features
#
# 3.One Hot Encoding
#
# 4.Selecting Features for modeling
#
# Note: The main goal is of feature Engineering is to get the best result from algorithms.

# %%
# filling missing data in datasist

df_data=ds.feature_engineering.fill_missing_cats(df_data)
df_data=ds.feature_engineering.fill_missing_num(df_data)

# %%
df_data['Age_of_Car']=2024-df_data['Year']

# %%
df_data.head()
df_data.columns
df_data=df_data[[ 'Year', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
       'Seller_Type', 'Transmission', 'Owner', 'Selling_Price', 'Age_of_Car']]

# %%
df_data=pd.get_dummies(df_data,drop_first=True)

df_data = df_data.astype(int)
df_data
# Out:
#        Year  Present_Price  Kms_Driven  Owner  Selling_Price  Age_of_Car  \
# 0      2016          12417       33217      0          11717           8
# 1      2017          10633       12905      0           9931           7
# 2      2015          10881       62053      0          10180           9
# 3      2016          11107       43897      0          10404           8
# 4      2016          10316        4108      0           9614           8
# ...     ...            ...         ...    ...            ...         ...
# 99995  2017          10968        2900      0          10267           7
# 99996  2015          12575        6862      0          11875           9
# 99997  2014           9229       46801      0           8526          10
# 99998  2015          10702       26365      0          10000           9
# 99999  2015          11649       20267      0          10945           9
#
#        Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                     0                 1                       1
# 1                     0                 1                       0
# 2                     1                 0                       0
# 3                     1                 0                       0
# 4                     0                 1                       0
# ...                 ...               ...                     ...
# 99995                 0                 1                       0
# 99996                 0                 1                       0
# 99997                 1                 0                       0
# 99998                 0                 1                       0
# 99999                 0                 1                       0
#
#        Transmission_Manual
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 99995                    1
# 99996                    1
# 99997                    1
# 99998                    1
# 99999                    1
#
# [100000 rows x 10 columns]

# %%
df_data.dtypes
# Out:
# Year                      int32
# Present_Price             int32
# Kms_Driven                int32
# Owner                     int32
# Selling_Price             int32
# Age_of_Car                int32
# Fuel_Type_Diesel          int32
# Fuel_Type_Petrol          int32
# Seller_Type_Individual    int32
# Transmission_Manual       int32
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[16,10]
sns.heatmap(df_data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Modelling

# %%
df_data.columns
# Out:
# Index(['Year', 'Present_Price', 'Kms_Driven', 'Owner', 'Selling_Price',
#        'Age_of_Car', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
#        'Seller_Type_Individual', 'Transmission_Manual'],
#       dtype='object')

# %%
# creating a multidimentional array with present price
#note:present price has a correlation of one which will make the model depend on it and not train properly on other features that contributes to the selling price.
df_data=df_data[['Year', 'Present_Price', 'Kms_Driven', 'Owner', 'Selling_Price',
       'Age_of_Car', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
       'Seller_Type_Individual', 'Transmission_Manual']]

# creating a multidimentional array without present price to test for the difference based on the influence of present price.
df_data2=df_data[['Year','Kms_Driven', 'Owner', 'Selling_Price',
       'Age_of_Car', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
       'Seller_Type_Individual', 'Transmission_Manual']]

# %%
X=df_data2.drop('Selling_Price',axis=1)
y=df_data2['Selling_Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y, test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred=model.predict(x_test)

# %%
#import metric for measuring model accuracy
from sklearn import metrics
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# RMSE: 379.48711837613166

# %%
import joblib
model_file=open("random_forest_carprice_model.pkl","wb")
joblib.dump(model,model_file) 
model_file.close()

# %% [markdown]
# ## Model with Present Selling

# %%
#plot graph of feature importance for better visualization
feat_importances=pd.Series(model.feature_importances_,index=x_train.columns)# index=x_train.columns means we are using our column names as index for this viz
feat_importances.nlargest(5).plot(kind='barh',figsize=(20,5))  # check effect of the top 5 features on the model
plt.show()

# %% [markdown]
# ## Model without Present Selling

# %%
#plot graph of feature importance for better visualization
feat_importances=pd.Series(model.feature_importances_,index=x_train.columns)# index=x_train.columns means we are using our column names as index for this viz
feat_importances.nlargest(5).plot(kind='barh',figsize=(20,5))  # check effect of the top 5 features on the model
plt.show()

# %% [markdown]
# #### The Visualization(using df_data) above show that the model only considered Present price as a relevant feature to predict price which is not good!This is due to its perfect correlation with the target variable,selling price,hence this factor is to be considered in feature selection. Using df_data2(which we drop present price)...we can see the contribution of all other relevant feature. A downside to your model depending on feature with strong correlation is that in production or live setting, that particular feature is not provided the model cant carry out prediction since sole reliance is placed on that single feature.
